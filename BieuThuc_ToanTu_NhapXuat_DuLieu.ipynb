# %% [markdown]
# W2A1

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# W2A2

# %%
name = input("Nhập tên của bạn: ")
print("Xin chào,", name, "!")
# Out:
# Xin chào, nguyên !

# %% [markdown]
# W2A3
