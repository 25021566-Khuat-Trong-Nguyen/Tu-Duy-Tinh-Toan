# %% [markdown]
# W2A1

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# W2A2

# %%
name = input("Nhập tên của bạn: ")
print("Xin chào,", name, "!")
# Out:
# Xin chào, nguyên !

# %% [markdown]
# W2A3

# %%
a = int(input("Nhập số nguyên a: ")) #a=5
b = int(input("Nhập số nguyên b: ")) #b=2
print("Tổng:", a + b)
print("Hiệu:", a - b)
print("Tích:", a * b)
print("Phần nguyên:", a // b)
print("Phần dư:", a % b)
print("Kết quả chia thực:", format(a / b, ".2f")) # có thể dùng hàm round(a / b, 2)
# Out:
# Tổng: 7
# Hiệu: 3
# Tích: 10
# Phần nguyên: 2
# Phần dư: 1
# Kết quả chia thực: 2.50

# %% [markdown]
# W2A4

# %%
a1, b1, c1, a2, b2, a3 = map(float, input().split())
TB = round(((a1+b1+c1)+(a2+b2)*2+a3*3)/10, 2)
print(TB)
# Out:
# 6.01

# %% [markdown]
# W2A5

# %%
a, b = map(int, input().split())
print(a**b)
# Out:
# 15625

# %% [markdown]
# W2A6

# %%
c=input()
if len(c) !=1 or not c.isalpha() or not c.islower():
    print("nhap lai chu cai thuong")
else:
    print((ord(c)))
    print(c.upper())
# Out:
# 103
# G

# %% [markdown]
# W2A7

# %%
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print(A,B)
# Out:
# 512 512

# %% [markdown]
# W2A8

# %%
C=float(input("Nhập nhiệt độ C: "))
F = round(9/5*C + 32, 2)
print("Nhiệt độ F là:", F)
# Out:
# Nhiệt độ F là: 86.0

# %% [markdown]
# W2A9

# %%
USD = float(input("Nhập số tiền USD: "))
So_tien_dat_tra = round(USD-10 -(USD*0.03)-(USD*0.01), 2)
print( So_tien_dat_tra )
# Out:
# 57.2

# %% [markdown]
# W2A10

# %%
Ten=input('3 ten bat ky: ').split()
print(Ten[2], Ten[1], Ten[0])
# Out:
# tuan nguyen quang

# %% [markdown]
# W2A11

# %%
h,m= map(int, input().split())
s = h * 3600 + m * 60
print(s)
# Out:
# 245880

# %% [markdown]
# W2A12

# %%
n = int(input())
so_mieng_dan = 6 * (n ** 2)
print(so_mieng_dan)
# Out:
# 54

# %% [markdown]
# W2A13

# %%
a, b = map(int, input().split())
print((a * b) % 10)
# Out:
# 2

# %% [markdown]
# W2A14

# %%
a, b = map(int, input().split())
a = a + b
b = a - b
a = a - b
print(a, b)
# Out:
# 5 4

# %% [markdown]
# W2A15

# %%
n = int(input())
so_sao = 3 * n * (n - 1) + 1
print(so_sao)
# Out:
# 19

# %% [markdown]
# W2A16

# %%
print("""Spring
Summer
Autumn
Winter""")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# W2A17

# %%
print("    *    ")
print("   * *   ")
print("  *   *  ")
print(" *     * ")
print("* * * * *")
print(" *     * ")
print("  *   *  ")
print("   * *   ")
print("    *    ")
# Out:
#     *
#    * *
#   *   *
#  *     *
# * * * * *
#  *     *
#   *   *
#    * *
#     *

# %% [markdown]
# W2A18

# %%
print("""###  # # ### ### 
  #  #  # #   # 
  #  #  # #   # 
  #  # #  #   #       
   """)
# Out:
# ###  # # ### ###
#   #  #  # #   #
#   #  #  # #   #
#   #  # #  #   #

# %% [markdown]
# W2A19

# %%
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# W2A20

# %%
m = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

for i in m:
    print(i)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# Tuần 4

# %%
Diem=float(input("Nhập điểm số: "))
if Diem >= 8:
    print("Giỏi")
elif Diem >= 6.5:
    print("Khá")
elif Diem >= 5:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Giỏi
